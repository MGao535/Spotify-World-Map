# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pprint

# %%
market = [ "AD", "AR", "AT", "AU", "BE", "BG", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", 
      "CZ", "DE", "DK", "DO", "EC", "EE", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", 
      "ID", "IE", "IS", "IT", "JP", "LI", "LT", "LU", "LV", "MC", "MT", "MX", "MY", "NI", "NL", 
      "NO", "NZ", "PA", "PE", "PH", "PL", "PT", "PY", "SE", "SG", "SK", "SV", "TH", "TR", "TW", 
      "US", "UY", "VN" ]

CLIENT_ID = "d76e0263612746c1891673bca5220cd0"
CLIENT_SECRET = "7c34c892933d446fae874d28b3f6a9b2"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

track = "0GZmR7eKQCow1D7AHkwObk"
playlist = spotify.playlist_tracks('37i9dQZEVXbMMy2roB9myp', market=None, additional_types=('track', ))
# res = spotify.audio_features(track)
pprint.pprint(playlist['items'][0]['track'])
# Out:
# /Users/shawn/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
# [{'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hdhHgpxyniooUiQVaPxQ0'},
#                                    'href': 'https://api.spotify.com/v1/artists/5hdhHgpxyniooUiQVaPxQ0',
#                                    'id': '5hdhHgpxyniooUiQVaPxQ0',
#                                    'name': 'Nio Garcia',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5hdhHgpxyniooUiQVaPxQ0'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#                                    'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#                                    'id': '2R21vXR83lH98kGeO99Y66',
#                                    'name': 'Anuel AA',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#                                    'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#                                    'id': '7iK8PXO48WeuP03g8YR51W',
#                                    'name': 'Myke Towers',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FR',
#                                             'GB',
#                                             'GR',
#                                             'GT',
#                                             'HK',
#                                             'HN',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IS',
#                                             'IT',
#                                             'JO',
#                                             'JP',
#                                             'KW',
#                                             'LB',
#                                             'LI',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'MA',
#                                             'MC',
#                                             'MT',
#                                             'MX',
#                                             'MY',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'SA',
#                                             'SE',
#                                             'SG',
#                                             'SK',
#                                             'SV',
#                                             'TH',
#                                             'TN',
#                                             'TR',
#                                             'TW',
#                                             'US',
#                                             'UY',
#                                             'VN',
#                                             'ZA'],
#                       'external_urls': {'spotify': 'https://open.spotify.com/album/5emzM1P5GGeroiivNQgCq4'},
#                       'href': 'https://api.spotify.com/v1/albums/5emzM1P5GGeroiivNQgCq4',
#                       'id': '5emzM1P5GGeroiivNQgCq4',
#                       'images': [{'height': 640,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b2735a89169ff864c80931b2b073',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e025a89169ff864c80931b2b073',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d000048515a89169ff864c80931b2b073',
#                                   'width': 64}],
#                       'name': 'La Jeepeta (Remix)',
#                       'release_date': '2020-04-24',
#                       'release_date_precision': 'day',
#                       'total_tracks': 1,
#                       'type': 'album',
#                       'uri': 'spotify:album:5emzM1P5GGeroiivNQgCq4'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hdhHgpxyniooUiQVaPxQ0'},
#                          'href': 'https://api.spotify.com/v1/artists/5hdhHgpxyniooUiQVaPxQ0',
#                          'id': '5hdhHgpxyniooUiQVaPxQ0',
#                          'name': 'Nio Garcia',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:5hdhHgpxyniooUiQVaPxQ0'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#                          'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#                          'id': '2R21vXR83lH98kGeO99Y66',
#                          'name': 'Anuel AA',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'},
#                          'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W',
#                          'id': '7iK8PXO48WeuP03g8YR51W',
#                          'name': 'Myke Towers',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GKIlPFdcewHtpDVCQ8zmJ'},
#                          'href': 'https://api.spotify.com/v1/artists/1GKIlPFdcewHtpDVCQ8zmJ',
#                          'id': '1GKIlPFdcewHtpDVCQ8zmJ',
#                          'name': 'Brray',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:1GKIlPFdcewHtpDVCQ8zmJ'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Wb38LDP3N4tkobValgE9D'},
#                          'href': 'https://api.spotify.com/v1/artists/3Wb38LDP3N4tkobValgE9D',
#                          'id': '3Wb38LDP3N4tkobValgE9D',
#                          'name': 'Juanka',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:3Wb38LDP3N4tkobValgE9D'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 345240,
#             'episode': False,
#             'explicit': True,
#             'external_ids': {'isrc': 'QM6MZ2057011'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/1mohfLaTJtB2RplHLQVM70'},
#             'href': 'https://api.spotify.com/v1/tracks/1mohfLaTJtB2RplHLQVM70',
#             'id': '1mohfLaTJtB2RplHLQVM70',
#             'is_local': False,
#             'name': 'La Jeepeta - Remix',
#             'popularity': 87,
#             'preview_url': 'https://p.scdn.co/mp3-preview/ac250bbe1987ff1067ea0fff6ac868a1411372ae?cid=d76e0263612746c1891673bca5220cd0',
#             'track': True,
#             'track_number': 1,
#             'type': 'track',
#             'uri': 'spotify:track:1mohfLaTJtB2RplHLQVM70'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UZIAOlrnyZmyzt1nuXr9y'},
#                                    'href': 'https://api.spotify.com/v1/artists/2UZIAOlrnyZmyzt1nuXr9y',
#                                    'id': '2UZIAOlrnyZmyzt1nuXr9y',
#                                    'name': 'Nicki Nicole',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2UZIAOlrnyZmyzt1nuXr9y'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FR',
#                                             'GB',
#                                             'GR',
#                                             'GT',
#                                             'HK',
#                                             'HN',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IS',
#                                             'IT',
#                                             'JO',
#                                             'JP',
#                                             'KW',
#                                             'LB',
#                                             'LI',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'MA',
#                                             'MC',
#                                             'MT',
#                                             'MX',
#                                             'MY',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'SA',
#                                             'SE',
#                                             'SG',
#                                             'SK',
#                                             'SV',
#                                             'TH',
#                                             'TN',
#                                             'TR',
#                                             'TW',
#                                             'US',
#                                             'UY',
#                                             'VN',
#                                             'ZA'],
#                       'external_urls': {'spotify': 'https://open.spotify.com/album/3VH9BRaAzvy7n9X5DNdHxm'},
#                       'href': 'https://api.spotify.com/v1/albums/3VH9BRaAzvy7n9X5DNdHxm',
#                       'id': '3VH9BRaAzvy7n9X5DNdHxm',
#                       'images': [{'height': 640,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b273dfcbe5bdc2679e14090dad39',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e02dfcbe5bdc2679e14090dad39',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d00004851dfcbe5bdc2679e14090dad39',
#                                   'width': 64}],
#                       'name': 'Colocao',
#                       'release_date': '2020-05-13',
#                       'release_date_precision': 'day',
#                       'total_tracks': 1,
#                       'type': 'album',
#                       'uri': 'spotify:album:3VH9BRaAzvy7n9X5DNdHxm'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UZIAOlrnyZmyzt1nuXr9y'},
#                          'href': 'https://api.spotify.com/v1/artists/2UZIAOlrnyZmyzt1nuXr9y',
#                          'id': '2UZIAOlrnyZmyzt1nuXr9y',
#                          'name': 'Nicki Nicole',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2UZIAOlrnyZmyzt1nuXr9y'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 179966,
#             'episode': False,
#             'explicit': True,
#             'external_ids': {'isrc': 'UYB282000001'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/7MCFjPDImfjQv7GynHgVrR'},
#             'href': 'https://api.spotify.com/v1/tracks/7MCFjPDImfjQv7GynHgVrR',
#             'id': '7MCFjPDImfjQv7GynHgVrR',
#             'is_local': False,
#             'name': 'Colocao',
#             'popularity': 79,
#             'preview_url': 'https://p.scdn.co/mp3-preview/d9941b90040a830b1e229631c16b9a084389e277?cid=d76e0263612746c1891673bca5220cd0',
#             'track': True,
#             'track_number': 1,
#             'type': 'track',
#             'uri': 'spotify:track:7MCFjPDImfjQv7GynHgVrR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77ziqFxp5gaInVrF2lj4ht'},
#                                    'href': 'https://api.spotify.com/v1/artists/77ziqFxp5gaInVrF2lj4ht',
#                                    'id': '77ziqFxp5gaInVrF2lj4ht',
#                                    'name': 'Sech',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:77ziqFxp5gaInVrF2lj4ht'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FR',
#                                             'GB',
#                                             'GR',
#                                             'GT',
#                                             'HK',
#                                             'HN',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IS',
#                                             'IT',
#                                             'JO',
#                                             'JP',
#                                             'KW',
#                                             'LB',
#                                             'LI',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'MA',
#                                             'MC',
#                                             'MT',
#                                             'MX',
#                                             'MY',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'SA',
#                                             'SE',
#                                             'SG',
#                                             'SK',
#                                             'SV',
#                                             'TH',
#                                             'TN',
#                                             'TR',
#                                             'TW',
#                                             'US',
#                                             'UY',
#                                             'VN',
#                                             'ZA'],
#                       'external_urls': {'spotify': 'https://open.spotify.com/album/3D1NZYi3GsenO5uWDFrRI6'},
#                       'href': 'https://api.spotify.com/v1/albums/3D1NZYi3GsenO5uWDFrRI6',
#                       'id': '3D1NZYi3GsenO5uWDFrRI6',
#                       'images': [{'height': 640,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b273a00b470b311631817cc9fe93',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e02a00b470b311631817cc9fe93',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d00004851a00b470b311631817cc9fe93',
#                                   'width': 64}],
#                       'name': '1 of 1',
#                       'release_date': '2020-05-21',
#                       'release_date_precision': 'day',
#                       'total_tracks': 21,
#                       'type': 'album',
#                       'uri': 'spotify:album:3D1NZYi3GsenO5uWDFrRI6'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77ziqFxp5gaInVrF2lj4ht'},
#                          'href': 'https://api.spotify.com/v1/artists/77ziqFxp5gaInVrF2lj4ht',
#                          'id': '77ziqFxp5gaInVrF2lj4ht',
#                          'name': 'Sech',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:77ziqFxp5gaInVrF2lj4ht'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 184254,
#             'episode': False,
#             'explicit': False,
#             'external_ids': {'isrc': 'QM9WM2000013'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/3ZG8N7aWw2meb6UrI5ZmnZ'},
#             'href': 'https://api.spotify.com/v1/tracks/3ZG8N7aWw2meb6UrI5ZmnZ',
#             'id': '3ZG8N7aWw2meb6UrI5ZmnZ',
#             'is_local': False,
#             'name': 'Relación',
#             'popularity': 76,
#             'preview_url': 'https://p.scdn.co/mp3-preview/737fd8725a6e30b84c7663a3984b94b00ad1829b?cid=d76e0263612746c1891673bca5220cd0',
#             'track': True,
#             'track_number': 9,
#             'type': 'track',
#             'uri': 'spotify:track:3ZG8N7aWw2meb6UrI5ZmnZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#                                    'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#                                    'id': '2LRoIwlKmHjgvigdNGBHNo',
#                                    'name': 'Feid',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FR',
#                                             'GB',
#                                             'GR',
#                                             'GT',
#                                             'HK',
#                                             'HN',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IS',
#                                             'IT',
#                                             'JO',
#                                             'JP',
#                                             'KW',
#                                             'LB',
#                                             'LI',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'MA',
#                                             'MC',
#                                             'MT',
#                                             'MX',
#                                             'MY',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'SA',
#                                             'SE',
#                                             'SG',
#                                             'SK',
#                                             'SV',
#                                             'TH',
#                                             'TN',
#                                             'TR',
#                                             'TW',
#                                             'US',
#                                             'UY',
#                                             'VN',
#                                             'ZA'],
#                       'external_urls': {'spotify': 'https://open.spotify.com/album/3js3vnaiDDghVu9ADH93Q5'},
#                       'href': 'https://api.spotify.com/v1/albums/3js3vnaiDDghVu9ADH93Q5',
#                       'id': '3js3vnaiDDghVu9ADH93Q5',
#                       'images': [{'height': 640,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b2738e8753ff69b7efb6f8e146cd',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e028e8753ff69b7efb6f8e146cd',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d000048518e8753ff69b7efb6f8e146cd',
#                                   'width': 64}],
#                       'name': 'FERXXO (VOL 1: M.O.R)',
#                       'release_date': '2020-04-23',
#                       'release_date_precision': 'day',
#                       'total_tracks': 16,
#                       'type': 'album',
#                       'uri': 'spotify:album:3js3vnaiDDghVu9ADH93Q5'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#                          'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#                          'id': '2LRoIwlKmHjgvigdNGBHNo',
#                          'name': 'Feid',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/14zUHaJZo1mnYtn6IBRaRP'},
#                          'href': 'https://api.spotify.com/v1/artists/14zUHaJZo1mnYtn6IBRaRP',
#                          'id': '14zUHaJZo1mnYtn6IBRaRP',
#                          'name': 'Justin Quiles',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:14zUHaJZo1mnYtn6IBRaRP'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 232653,
#             'episode': False,
#             'explicit': False,
#             'external_ids': {'isrc': 'USUM71924087'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/4TOmcZvw0gHa7GiXRbcYAW'},
#             'href': 'https://api.spotify.com/v1/tracks/4TOmcZvw0gHa7GiXRbcYAW',
#             'id': '4TOmcZvw0gHa7GiXRbcYAW',
#             'is_local': False,
#             'name': 'PORFA',
#             'popularity': 78,
#             'preview_url': None,
#             'track': True,
#             'track_number': 5,
#             'type': 'track',
#             'uri': 'spotify:track:4TOmcZvw0gHa7GiXRbcYAW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#                                    'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#                                    'id': '1mcTU81TzQhprhouKaTkpq',
#                                    'name': 'Rauw Alejandro',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0KPX4Ucy9dk82uj4GpKesn'},
#                                    'href': 'https://api.spotify.com/v1/artists/0KPX4Ucy9dk82uj4GpKesn',
#                                    'id': '0KPX4Ucy9dk82uj4GpKesn',
#                                    'name': 'Dalex',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0KPX4Ucy9dk82uj4GpKesn'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pQWsZQehhS4wavwh7Fnxd'},
#                                    'href': 'https://api.spotify.com/v1/artists/1pQWsZQehhS4wavwh7Fnxd',
#                                    'id': '1pQWsZQehhS4wavwh7Fnxd',
#                                    'name': 'Lenny Tavárez',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1pQWsZQehhS4wavwh7Fnxd'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
# ...
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b27335692baca45542527d742d0d',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e0235692baca45542527d742d0d',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000485135692baca45542527d742d0d',
#                                   'width': 64}],
#                       'name': 'Colores',
#                       'release_date': '2020-03-19',
#                       'release_date_precision': 'day',
#                       'total_tracks': 10,
#                       'type': 'album',
#                       'uri': 'spotify:album:2mX8ktJoWvyidWBU9U8Jis'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#                          'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#                          'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#                          'name': 'J Balvin',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 157733,
#             'episode': False,
#             'explicit': False,
#             'external_ids': {'isrc': 'USUM72001730'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/6zEgnpM0qYmHLDnh8WPejL'},
#             'href': 'https://api.spotify.com/v1/tracks/6zEgnpM0qYmHLDnh8WPejL',
#             'id': '6zEgnpM0qYmHLDnh8WPejL',
#             'is_local': False,
#             'name': 'Amarillo',
#             'popularity': 88,
#             'preview_url': None,
#             'track': True,
#             'track_number': 1,
#             'type': 'track',
#             'uri': 'spotify:track:6zEgnpM0qYmHLDnh8WPejL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28gNT5KBp7IjEOQoevXf9N'},
#                                    'href': 'https://api.spotify.com/v1/artists/28gNT5KBp7IjEOQoevXf9N',
#                                    'id': '28gNT5KBp7IjEOQoevXf9N',
#                                    'name': 'Camilo',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:28gNT5KBp7IjEOQoevXf9N'}],
#                       'available_markets': ['AD',
#                                             'AE',
#                                             'AR',
#                                             'AT',
#                                             'AU',
#                                             'BE',
#                                             'BG',
#                                             'BH',
#                                             'BO',
#                                             'BR',
#                                             'CA',
#                                             'CH',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DE',
#                                             'DK',
#                                             'DO',
#                                             'DZ',
#                                             'EC',
#                                             'EE',
#                                             'EG',
#                                             'ES',
#                                             'FI',
#                                             'FR',
#                                             'GB',
#                                             'GR',
#                                             'GT',
#                                             'HK',
#                                             'HN',
#                                             'HU',
#                                             'ID',
#                                             'IE',
#                                             'IL',
#                                             'IN',
#                                             'IS',
#                                             'IT',
#                                             'JO',
#                                             'JP',
#                                             'KW',
#                                             'LB',
#                                             'LI',
#                                             'LT',
#                                             'LU',
#                                             'LV',
#                                             'MA',
#                                             'MC',
#                                             'MT',
#                                             'MX',
#                                             'MY',
#                                             'NI',
#                                             'NL',
#                                             'NO',
#                                             'NZ',
#                                             'OM',
#                                             'PA',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PS',
#                                             'PT',
#                                             'PY',
#                                             'QA',
#                                             'RO',
#                                             'SA',
#                                             'SE',
#                                             'SG',
#                                             'SK',
#                                             'SV',
#                                             'TH',
#                                             'TN',
#                                             'TR',
#                                             'TW',
#                                             'US',
#                                             'UY',
#                                             'VN',
#                                             'ZA'],
#                       'external_urls': {'spotify': 'https://open.spotify.com/album/6xS6mQz1fQZ6eZE654J15I'},
#                       'href': 'https://api.spotify.com/v1/albums/6xS6mQz1fQZ6eZE654J15I',
#                       'id': '6xS6mQz1fQZ6eZE654J15I',
#                       'images': [{'height': 640,
#                                   'url': 'https://i.scdn.co/image/ab67616d0000b273b4da01f3f98d18af9432e3dd',
#                                   'width': 640},
#                                  {'height': 300,
#                                   'url': 'https://i.scdn.co/image/ab67616d00001e02b4da01f3f98d18af9432e3dd',
#                                   'width': 300},
#                                  {'height': 64,
#                                   'url': 'https://i.scdn.co/image/ab67616d00004851b4da01f3f98d18af9432e3dd',
#                                   'width': 64}],
#                       'name': 'Por Primera Vez',
#                       'release_date': '2020-04-17',
#                       'release_date_precision': 'day',
#                       'total_tracks': 10,
#                       'type': 'album',
#                       'uri': 'spotify:album:6xS6mQz1fQZ6eZE654J15I'},
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28gNT5KBp7IjEOQoevXf9N'},
#                          'href': 'https://api.spotify.com/v1/artists/28gNT5KBp7IjEOQoevXf9N',
#                          'id': '28gNT5KBp7IjEOQoevXf9N',
#                          'name': 'Camilo',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:28gNT5KBp7IjEOQoevXf9N'},
#                         {'external_urls': {'spotify': 'https://open.spotify.com/artist/4QVBYiagIaa6ZGSPMbybpy'},
#                          'href': 'https://api.spotify.com/v1/artists/4QVBYiagIaa6ZGSPMbybpy',
#                          'id': '4QVBYiagIaa6ZGSPMbybpy',
#                          'name': 'Pedro Capó',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:4QVBYiagIaa6ZGSPMbybpy'}],
#             'available_markets': ['AD',
#                                   'AE',
#                                   'AR',
#                                   'AT',
#                                   'AU',
#                                   'BE',
#                                   'BG',
#                                   'BH',
#                                   'BO',
#                                   'BR',
#                                   'CA',
#                                   'CH',
#                                   'CL',
#                                   'CO',
#                                   'CR',
#                                   'CY',
#                                   'CZ',
#                                   'DE',
#                                   'DK',
#                                   'DO',
#                                   'DZ',
#                                   'EC',
#                                   'EE',
#                                   'EG',
#                                   'ES',
#                                   'FI',
#                                   'FR',
#                                   'GB',
#                                   'GR',
#                                   'GT',
#                                   'HK',
#                                   'HN',
#                                   'HU',
#                                   'ID',
#                                   'IE',
#                                   'IL',
#                                   'IN',
#                                   'IS',
#                                   'IT',
#                                   'JO',
#                                   'JP',
#                                   'KW',
#                                   'LB',
#                                   'LI',
#                                   'LT',
#                                   'LU',
#                                   'LV',
#                                   'MA',
#                                   'MC',
#                                   'MT',
#                                   'MX',
#                                   'MY',
#                                   'NI',
#                                   'NL',
#                                   'NO',
#                                   'NZ',
#                                   'OM',
#                                   'PA',
#                                   'PE',
#                                   'PH',
#                                   'PL',
#                                   'PS',
#                                   'PT',
#                                   'PY',
#                                   'QA',
#                                   'RO',
#                                   'SA',
#                                   'SE',
#                                   'SG',
#                                   'SK',
#                                   'SV',
#                                   'TH',
#                                   'TN',
#                                   'TR',
#                                   'TW',
#                                   'US',
#                                   'UY',
#                                   'VN',
#                                   'ZA'],
#             'disc_number': 1,
#             'duration_ms': 179339,
#             'episode': False,
#             'explicit': False,
#             'external_ids': {'isrc': 'USSD11900263'},
#             'external_urls': {'spotify': 'https://open.spotify.com/track/1Ol5LmdNDNpFu1oNwfgkux'},
#             'href': 'https://api.spotify.com/v1/tracks/1Ol5LmdNDNpFu1oNwfgkux',
#             'id': '1Ol5LmdNDNpFu1oNwfgkux',
#             'is_local': False,
#             'name': 'Tutu',
#             'popularity': 75,
#             'preview_url': 'https://p.scdn.co/mp3-preview/eb2dcc7dd8c17cfa9b98a5748cda6f74918ae8c3?cid=d76e0263612746c1891673bca5220cd0',
#             'track': True,
#             'track_number': 9,
#             'type': 'track',
#             'uri': 'spotify:track:1Ol5LmdNDNpFu1oNwfgkux'},
#   'video_thumbnail': {'url': None}}]

# %%
pprint.pprint(playlist['items'][1]['track']['album']['name'])
# Out:
# 'Colocao'

# %%
pprint.pprint(playlist['items'][1]['track']['album']['uri'])
# Out:
# 'spotify:album:3VH9BRaAzvy7n9X5DNdHxm'

# %%
songs = []
for track in range(50):
    songs.append(playlist['items'][track]['track']['album']['name'])
pprint.pprint(songs)
# Out:
# ['La Jeepeta (Remix)',
#  'Colocao',
#  '1 of 1',
#  'FERXXO (VOL 1: M.O.R)',
#  'Elegí (feat. Dímelo Flow)',
#  'Tak Tiki Tak',
#  'YHLQMDLG',
#  'Por Primera Vez',
#  'Colores',
#  'Tattoo',
#  'Inolvidable',
#  'YHLQMDLG',
#  'Emmanuel',
#  'Tusa',
#  'Hola (Remix)',
#  'La Jeepeta (Remix)',
#  'Easy Money Baby',
#  'Por Primera Vez',
#  'C.R.O: Bzrp Music Sessions, Vol. 29',
#  'Colores',
#  'After Hours',
#  'Sigues Con El',
#  'Como Llora',
#  'Colegio',
#  'El Efecto (Remix)',
#  'Roses (Imanbek Remix)',
#  'Ya No Más',
#  'YHLQMDLG',
#  'Fine Line',
#  'Future Nostalgia',
#  'YHLQMDLG',
#  'High',
#  'Flasheaste Amor',
#  'TKN (feat. Travis Scott)',
#  'Loco',
#  'Dance Monkey',
#  'Cómo estás',
#  'Fantasias',
#  'Bonus Trap',
#  'LOST',
#  'Si Me Dices Que Sí',
#  'death bed (coffee for your head) (feat. beabadoobee)',
#  'La Cama (Remix)',
#  'La Pared 360',
#  'Colores',
#  'Recuerdo',
#  'Modo Avión',
#  'Dónde Estás',
#  'Colores',
#  'Por Primera Vez']

# %%
song_id = []
for track in range(50):
    song_id.append(playlist['items'][track]['track']['id'])
pprint.pprint(song_id)
# Out:
# ['1mohfLaTJtB2RplHLQVM70',
#  '7MCFjPDImfjQv7GynHgVrR',
#  '3ZG8N7aWw2meb6UrI5ZmnZ',
#  '4TOmcZvw0gHa7GiXRbcYAW',
#  '50ZC4PM7hywH27RcCfViau',
#  '0aCTSZQTlmnjQucALTF00s',
#  '0SqqAgdovOE24BzxIClpjw',
#  '0jT8Nl0shPS8115is0wD2Q',
#  '380HmhwTE2NJgawn1NwkXi',
#  '7na7Bk98usp84FaOJFPv3d',
#  '0OTtnwUO8natNWSwdZvXVF',
#  '2DEZmgHKAvm41k4J3R2E9Y',
#  '06s3QtMJVXw1AJX3UfvZG1',
#  '7k4t7uLgtOxPwTpFmtJNTY',
#  '5stPVcRqb4qixbafP9e8lt',
#  '5PcInxO1rmTE6Kl2y9akaI',
#  '3JHpk0DOTOzyh0777JFAky',
#  '0pgj4EzB1XRqgZemoMNG5D',
#  '0qPbQWcqNDVrReSSvMoJxk',
#  '35KmOEIUqAGn02t7n4qaIr',
#  '0VjIjW4GlUZAMYd2vXMi3b',
#  '7sQKy5vlPQllr0k9IjYJv3',
#  '52zq2a71SGs3f1vJuv59ui',
#  '5379uuUPHodsdVhy8pIAAr',
#  '74j34STf8L6uADnTN69ohv',
#  '24Yi9hE78yPEbZ4kxyoXAI',
#  '4gQG2Ic7hnJMAcqunk4ERT',
#  '6NfrH0ANGmgBXyxgV2PeXt',
#  '6UelLqGlWMcVH1E5c4H7lY',
#  '3PfIrDoz19wz7qK7tYeu62',
#  '38RIEav39FGi86jppxO0du',
#  '5vPtzdjJ9tm7XCoKDH22Gb',
#  '2ACgvo2Kx4LgWqQ2amvM5C',
#  '4w47S36wQGBhGg073q3nt7',
#  '2J9B63FawlTaPdg4eH5X03',
#  '1rgnBhdG2JDFTbYkYRZAku',
#  '6bLvfGI2XeU5DTl8feuNrk',
#  '6mAN61JH0dzyZpWslS11jy',
#  '3EO0tGvdBCw6vdChaNvVlc',
#  '5m3jpKkgkfoMcym1qjToFg',
#  '56Ta1O7Jxxpjnc6cWdDKUo',
#  '7eJMfftS33KTjuF7lTsMCx',
#  '2tGENA8xef0wABdHvyXwv9',
#  '2w8SKQCnT2YQK1qCqKl2uW',
#  '2lCkncy6bIB0LTMT7kvrD1',
#  '3DjInVTE03icrWsq2UZV9n',
#  '4GGwM2Krtlx9G9ii1RaEOx',
#  '16DNJ8y6k97DxuMyV49W7V',
#  '6zEgnpM0qYmHLDnh8WPejL',
#  '1Ol5LmdNDNpFu1oNwfgkux']

# %%
audio_fets = spotify.audio_features(song_id)
pprint.pprint(audio_fets)
# Out:
# [{'acousticness': 0.3,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mohfLaTJtB2RplHLQVM70',
#   'danceability': 0.815,
#   'duration_ms': 345241,
#   'energy': 0.715,
#   'id': '1mohfLaTJtB2RplHLQVM70',
#   'instrumentalness': 4.83e-06,
#   'key': 4,
#   'liveness': 0.091,
#   'loudness': -4.65,
#   'mode': 0,
#   'speechiness': 0.207,
#   'tempo': 176.007,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1mohfLaTJtB2RplHLQVM70',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1mohfLaTJtB2RplHLQVM70',
#   'valence': 0.786},
#  {'acousticness': 0.28,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MCFjPDImfjQv7GynHgVrR',
#   'danceability': 0.811,
#   'duration_ms': 179967,
#   'energy': 0.712,
#   'id': '7MCFjPDImfjQv7GynHgVrR',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.106,
#   'loudness': -3.773,
#   'mode': 0,
#   'speechiness': 0.054,
#   'tempo': 90.02,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7MCFjPDImfjQv7GynHgVrR',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7MCFjPDImfjQv7GynHgVrR',
#   'valence': 0.576},
#  {'acousticness': 0.125,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZG8N7aWw2meb6UrI5ZmnZ',
#   'danceability': 0.805,
#   'duration_ms': 184255,
#   'energy': 0.562,
#   'id': '3ZG8N7aWw2meb6UrI5ZmnZ',
#   'instrumentalness': 4.96e-06,
#   'key': 7,
#   'liveness': 0.148,
#   'loudness': -3.117,
#   'mode': 0,
#   'speechiness': 0.105,
#   'tempo': 172.094,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZG8N7aWw2meb6UrI5ZmnZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3ZG8N7aWw2meb6UrI5ZmnZ',
#   'valence': 0.767},
#  {'acousticness': 0.0903,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TOmcZvw0gHa7GiXRbcYAW',
#   'danceability': 0.795,
#   'duration_ms': 232653,
#   'energy': 0.542,
#   'id': '4TOmcZvw0gHa7GiXRbcYAW',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.117,
#   'loudness': -8.106,
#   'mode': 0,
#   'speechiness': 0.193,
#   'tempo': 167.823,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4TOmcZvw0gHa7GiXRbcYAW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4TOmcZvw0gHa7GiXRbcYAW',
#   'valence': 0.55},
#  {'acousticness': 0.237,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50ZC4PM7hywH27RcCfViau',
#   'danceability': 0.824,
#   'duration_ms': 197721,
#   'energy': 0.631,
#   'id': '50ZC4PM7hywH27RcCfViau',
#   'instrumentalness': 0.000116,
#   'key': 0,
#   'liveness': 0.0531,
#   'loudness': -2.791,
#   'mode': 1,
#   'speechiness': 0.0809,
#   'tempo': 171.965,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/50ZC4PM7hywH27RcCfViau',
#   'type': 'audio_features',
#   'uri': 'spotify:track:50ZC4PM7hywH27RcCfViau',
#   'valence': 0.678},
#  {'acousticness': 0.335,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aCTSZQTlmnjQucALTF00s',
#   'danceability': 0.802,
#   'duration_ms': 212406,
#   'energy': 0.579,
#   'id': '0aCTSZQTlmnjQucALTF00s',
#   'instrumentalness': 0.000311,
#   'key': 11,
#   'liveness': 0.173,
#   'loudness': -4.78,
#   'mode': 0,
#   'speechiness': 0.0869,
#   'tempo': 99.992,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0aCTSZQTlmnjQucALTF00s',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0aCTSZQTlmnjQucALTF00s',
#   'valence': 0.234},
#  {'acousticness': 0.021,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SqqAgdovOE24BzxIClpjw',
#   'danceability': 0.86,
#   'duration_ms': 172127,
#   'energy': 0.758,
#   'id': '0SqqAgdovOE24BzxIClpjw',
#   'instrumentalness': 6.54e-05,
#   'key': 11,
#   'liveness': 0.344,
#   'loudness': -5.16,
#   'mode': 1,
#   'speechiness': 0.0695,
#   'tempo': 97.014,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0SqqAgdovOE24BzxIClpjw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0SqqAgdovOE24BzxIClpjw',
#   'valence': 0.453},
#  {'acousticness': 0.237,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jT8Nl0shPS8115is0wD2Q',
#   'danceability': 0.606,
#   'duration_ms': 209766,
#   'energy': 0.853,
#   'id': '0jT8Nl0shPS8115is0wD2Q',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.251,
#   'loudness': -2.975,
#   'mode': 1,
#   'speechiness': 0.0545,
#   'tempo': 178.043,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0jT8Nl0shPS8115is0wD2Q',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0jT8Nl0shPS8115is0wD2Q',
#   'valence': 0.822},
#  {'acousticness': 0.193,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/380HmhwTE2NJgawn1NwkXi',
#   'danceability': 0.663,
#   'duration_ms': 150720,
#   'energy': 0.598,
#   'id': '380HmhwTE2NJgawn1NwkXi',
#   'instrumentalness': 8.02e-05,
#   'key': 11,
#   'liveness': 0.0856,
#   'loudness': -4.042,
#   'mode': 1,
#   'speechiness': 0.17,
#   'tempo': 172.245,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/380HmhwTE2NJgawn1NwkXi',
#   'type': 'audio_features',
#   'uri': 'spotify:track:380HmhwTE2NJgawn1NwkXi',
#   'valence': 0.4},
#  {'acousticness': 0.0217,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7na7Bk98usp84FaOJFPv3d',
#   'danceability': 0.755,
#   'duration_ms': 202887,
#   'energy': 0.617,
#   'id': '7na7Bk98usp84FaOJFPv3d',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0625,
#   'loudness': -5.144,
#   'mode': 1,
#   'speechiness': 0.182,
#   'tempo': 193.896,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7na7Bk98usp84FaOJFPv3d',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7na7Bk98usp84FaOJFPv3d',
#   'valence': 0.745},
#  {'acousticness': 0.678,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0OTtnwUO8natNWSwdZvXVF',
#   'danceability': 0.84,
#   'duration_ms': 225812,
#   'energy': 0.543,
#   'id': '0OTtnwUO8natNWSwdZvXVF',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.128,
#   'loudness': -4.941,
#   'mode': 1,
#   'speechiness': 0.0568,
#   'tempo': 139.929,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0OTtnwUO8natNWSwdZvXVF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0OTtnwUO8natNWSwdZvXVF',
#   'valence': 0.74},
#  {'acousticness': 0.0103,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DEZmgHKAvm41k4J3R2E9Y',
#   'danceability': 0.607,
#   'duration_ms': 295177,
#   'energy': 0.829,
#   'id': '2DEZmgHKAvm41k4J3R2E9Y',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.107,
#   'loudness': -4.074,
#   'mode': 1,
#   'speechiness': 0.379,
#   'tempo': 96.172,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2DEZmgHKAvm41k4J3R2E9Y',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2DEZmgHKAvm41k4J3R2E9Y',
#   'valence': 0.685},
#  {'acousticness': 0.464,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06s3QtMJVXw1AJX3UfvZG1',
#   'danceability': 0.691,
#   'duration_ms': 246000,
#   'energy': 0.765,
#   'id': '06s3QtMJVXw1AJX3UfvZG1',
#   'instrumentalness': 3.29e-06,
#   'key': 8,
#   'liveness': 0.203,
#   'loudness': -4.727,
#   'mode': 1,
#   'speechiness': 0.111,
#   'tempo': 174.021,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/06s3QtMJVXw1AJX3UfvZG1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:06s3QtMJVXw1AJX3UfvZG1',
#   'valence': 0.855},
#  {'acousticness': 0.295,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7k4t7uLgtOxPwTpFmtJNTY',
#   'danceability': 0.803,
#   'duration_ms': 200960,
#   'energy': 0.715,
#   'id': '7k4t7uLgtOxPwTpFmtJNTY',
#   'instrumentalness': 0.000134,
#   'key': 2,
#   'liveness': 0.0574,
#   'loudness': -3.28,
#   'mode': 1,
#   'speechiness': 0.298,
#   'tempo': 101.085,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7k4t7uLgtOxPwTpFmtJNTY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7k4t7uLgtOxPwTpFmtJNTY',
#   'valence': 0.574},
#  {'acousticness': 0.471,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5stPVcRqb4qixbafP9e8lt',
#   'danceability': 0.654,
#   'duration_ms': 249520,
#   'energy': 0.672,
#   'id': '5stPVcRqb4qixbafP9e8lt',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0781,
#   'loudness': -5.98,
#   'mode': 0,
#   'speechiness': 0.311,
#   'tempo': 181.857,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5stPVcRqb4qixbafP9e8lt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5stPVcRqb4qixbafP9e8lt',
#   'valence': 0.343},
#  {'acousticness': 0.147,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PcInxO1rmTE6Kl2y9akaI',
#   'danceability': 0.823,
#   'duration_ms': 177647,
#   'energy': 0.642,
#   'id': '5PcInxO1rmTE6Kl2y9akaI',
#   'instrumentalness': 0.000465,
#   'key': 0,
#   'liveness': 0.0732,
#   'loudness': -7.933,
#   'mode': 1,
#   'speechiness': 0.106,
#   'tempo': 102.007,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5PcInxO1rmTE6Kl2y9akaI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5PcInxO1rmTE6Kl2y9akaI',
#   'valence': 0.816},
#  {'acousticness': 0.398,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JHpk0DOTOzyh0777JFAky',
#   'danceability': 0.801,
#   'duration_ms': 214013,
#   'energy': 0.745,
#   'id': '3JHpk0DOTOzyh0777JFAky',
#   'instrumentalness': 0.00603,
#   'key': 6,
#   'liveness': 0.153,
#   'loudness': -3.733,
#   'mode': 0,
#   'speechiness': 0.063,
#   'tempo': 104.965,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3JHpk0DOTOzyh0777JFAky',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3JHpk0DOTOzyh0777JFAky',
#   'valence': 0.245},
#  {'acousticness': 0.143,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0pgj4EzB1XRqgZemoMNG5D',
#   'danceability': 0.72,
#   'duration_ms': 182709,
#   'energy': 0.606,
#   'id': '0pgj4EzB1XRqgZemoMNG5D',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.0824,
#   'loudness': -3.54,
#   'mode': 1,
#   'speechiness': 0.116,
#   'tempo': 165.882,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0pgj4EzB1XRqgZemoMNG5D',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0pgj4EzB1XRqgZemoMNG5D',
#   'valence': 0.805},
#  {'acousticness': 0.639,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qPbQWcqNDVrReSSvMoJxk',
#   'danceability': 0.778,
#   'duration_ms': 146341,
#   'energy': 0.734,
#   'id': '0qPbQWcqNDVrReSSvMoJxk',
#   'instrumentalness': 0.00132,
#   'key': 6,
#   'liveness': 0.117,
#   'loudness': -5.346,
#   'mode': 1,
#   'speechiness': 0.0622,
#   'tempo': 82.047,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0qPbQWcqNDVrReSSvMoJxk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0qPbQWcqNDVrReSSvMoJxk',
#   'valence': 0.622},
#  {'acousticness': 0.131,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35KmOEIUqAGn02t7n4qaIr',
#   'danceability': 0.885,
#   'duration_ms': 200267,
#   'energy': 0.68,
#   'id': '35KmOEIUqAGn02t7n4qaIr',
#   'instrumentalness': 1.77e-05,
#   'key': 11,
#   'liveness': 0.0875,
#   'loudness': -3.837,
#   'mode': 0,
#   'speechiness': 0.0848,
#   'tempo': 97.003,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/35KmOEIUqAGn02t7n4qaIr',
#   'type': 'audio_features',
#   'uri': 'spotify:track:35KmOEIUqAGn02t7n4qaIr',
#   'valence': 0.78},
#  {'acousticness': 0.00146,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#   'danceability': 0.514,
#   'duration_ms': 200040,
#   'energy': 0.73,
#   'id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'instrumentalness': 9.54e-05,
#   'key': 1,
#   'liveness': 0.0897,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'tempo': 171.005,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#   'valence': 0.334},
#  {'acousticness': 0.11,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sQKy5vlPQllr0k9IjYJv3',
#   'danceability': 0.883,
#   'duration_ms': 226533,
#   'energy': 0.668,
#   'id': '7sQKy5vlPQllr0k9IjYJv3',
#   'instrumentalness': 0.000529,
#   'key': 9,
#   'liveness': 0.0734,
#   'loudness': -2.957,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 87.972,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7sQKy5vlPQllr0k9IjYJv3',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7sQKy5vlPQllr0k9IjYJv3',
#   'valence': 0.676},
#  {'acousticness': 0.183,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52zq2a71SGs3f1vJuv59ui',
#   'danceability': 0.827,
#   'duration_ms': 187500,
#   'energy': 0.629,
#   'id': '52zq2a71SGs3f1vJuv59ui',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.084,
#   'loudness': -3.966,
#   'mode': 0,
#   'speechiness': 0.185,
#   'tempo': 88.064,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/52zq2a71SGs3f1vJuv59ui',
#   'type': 'audio_features',
#   'uri': 'spotify:track:52zq2a71SGs3f1vJuv59ui',
#   'valence': 0.486},
#  {'acousticness': 0.0858,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5379uuUPHodsdVhy8pIAAr',
#   'danceability': 0.643,
#   'duration_ms': 209027,
#   'energy': 0.769,
#   'id': '5379uuUPHodsdVhy8pIAAr',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.205,
#   'loudness': -3.533,
#   'mode': 1,
#   'speechiness': 0.0877,
#   'tempo': 185.669,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5379uuUPHodsdVhy8pIAAr',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5379uuUPHodsdVhy8pIAAr',
#   'valence': 0.532},
#  {'acousticness': 0.18,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74j34STf8L6uADnTN69ohv',
#   'danceability': 0.771,
#   'duration_ms': 289899,
#   'energy': 0.769,
#   'id': '74j34STf8L6uADnTN69ohv',
#   'instrumentalness': 1.57e-05,
#   'key': 0,
#   'liveness': 0.345,
#   'loudness': -3.504,
#   'mode': 0,
#   'speechiness': 0.0694,
#   'tempo': 167.969,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/74j34STf8L6uADnTN69ohv',
#   'type': 'audio_features',
#   'uri': 'spotify:track:74j34STf8L6uADnTN69ohv',
#   'valence': 0.931},
#  {'acousticness': 0.0167,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#   'danceability': 0.77,
#   'duration_ms': 176840,
#   'energy': 0.724,
#   'id': '24Yi9hE78yPEbZ4kxyoXAI',
#   'instrumentalness': 0.0107,
#   'key': 8,
#   'liveness': 0.353,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0495,
#   'tempo': 121.975,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#   'valence': 0.898},
#  {'acousticness': 0.138,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4gQG2Ic7hnJMAcqunk4ERT',
#   'danceability': 0.795,
#   'duration_ms': 158447,
#   'energy': 0.676,
#   'id': '4gQG2Ic7hnJMAcqunk4ERT',
#   'instrumentalness': 0.00373,
#   'key': 6,
#   'liveness': 0.0734,
#   'loudness': -6.429,
#   'mode': 1,
#   'speechiness': 0.0589,
#   'tempo': 100.045,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4gQG2Ic7hnJMAcqunk4ERT',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4gQG2Ic7hnJMAcqunk4ERT',
#   'valence': 0.882},
#  {'acousticness': 0.0861,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NfrH0ANGmgBXyxgV2PeXt',
#   'danceability': 0.685,
#   'duration_ms': 163084,
#   'energy': 0.848,
#   'id': '6NfrH0ANGmgBXyxgV2PeXt',
#   'instrumentalness': 7.14e-06,
#   'key': 8,
#   'liveness': 0.0783,
#   'loudness': -4.561,
#   'mode': 0,
#   'speechiness': 0.0858,
#   'tempo': 179.87,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6NfrH0ANGmgBXyxgV2PeXt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6NfrH0ANGmgBXyxgV2PeXt',
#   'valence': 0.761},
#  {'acousticness': 0.122,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UelLqGlWMcVH1E5c4H7lY',
#   'danceability': 0.548,
#   'duration_ms': 174000,
#   'energy': 0.816,
#   'id': '6UelLqGlWMcVH1E5c4H7lY',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.335,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'tempo': 95.39,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6UelLqGlWMcVH1E5c4H7lY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6UelLqGlWMcVH1E5c4H7lY',
#   'valence': 0.557},
#  {'acousticness': 0.0125,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PfIrDoz19wz7qK7tYeu62',
#   'danceability': 0.794,
#   'duration_ms': 183290,
#   'energy': 0.793,
#   'id': '3PfIrDoz19wz7qK7tYeu62',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.0952,
#   'loudness': -4.521,
#   'mode': 0,
#   'speechiness': 0.0842,
#   'tempo': 123.941,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3PfIrDoz19wz7qK7tYeu62',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3PfIrDoz19wz7qK7tYeu62',
#   'valence': 0.677},
#  {'acousticness': 0.267,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38RIEav39FGi86jppxO0du',
#   'danceability': 0.85,
#   'duration_ms': 210607,
#   'energy': 0.536,
#   'id': '38RIEav39FGi86jppxO0du',
#   'instrumentalness': 3.89e-05,
#   'key': 1,
#   'liveness': 0.0996,
#   'loudness': -5.161,
#   'mode': 1,
#   'speechiness': 0.0599,
#   'tempo': 96.029,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/38RIEav39FGi86jppxO0du',
#   'type': 'audio_features',
#   'uri': 'spotify:track:38RIEav39FGi86jppxO0du',
#   'valence': 0.505},
#  {'acousticness': 0.153,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5vPtzdjJ9tm7XCoKDH22Gb',
#   'danceability': 0.82,
#   'duration_ms': 187200,
#   'energy': 0.29,
#   'id': '5vPtzdjJ9tm7XCoKDH22Gb',
#   'instrumentalness': 7.77e-06,
#   'key': 9,
#   'liveness': 0.0996,
#   'loudness': -10.496,
#   'mode': 0,
#   'speechiness': 0.0689,
#   'tempo': 99.965,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5vPtzdjJ9tm7XCoKDH22Gb',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5vPtzdjJ9tm7XCoKDH22Gb',
#   'valence': 0.322},
#  {'acousticness': 0.183,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ACgvo2Kx4LgWqQ2amvM5C',
#   'danceability': 0.776,
#   'duration_ms': 175263,
#   'energy': 0.559,
#   'id': '2ACgvo2Kx4LgWqQ2amvM5C',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.0728,
#   'loudness': -7.548,
#   'mode': 1,
#   'speechiness': 0.0469,
#   'tempo': 142.481,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ACgvo2Kx4LgWqQ2amvM5C',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ACgvo2Kx4LgWqQ2amvM5C',
#   'valence': 0.76},
#  {'acousticness': 0.192,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w47S36wQGBhGg073q3nt7',
#   'danceability': 0.776,
#   'duration_ms': 129371,
#   'energy': 0.509,
#   'id': '4w47S36wQGBhGg073q3nt7',
#   'instrumentalness': 1.49e-06,
#   'key': 0,
#   'liveness': 0.115,
#   'loudness': -6.266,
#   'mode': 0,
#   'speechiness': 0.467,
#   'tempo': 94.634,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4w47S36wQGBhGg073q3nt7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4w47S36wQGBhGg073q3nt7',
#   'valence': 0.485},
#  {'acousticness': 0.158,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2J9B63FawlTaPdg4eH5X03',
#   'danceability': 0.82,
#   'duration_ms': 204000,
#   'energy': 0.565,
#   'id': '2J9B63FawlTaPdg4eH5X03',
#   'instrumentalness': 2.45e-05,
#   'key': 6,
#   'liveness': 0.0469,
#   'loudness': -5.965,
#   'mode': 1,
#   'speechiness': 0.17,
#   'tempo': 105.11,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2J9B63FawlTaPdg4eH5X03',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2J9B63FawlTaPdg4eH5X03',
#   'valence': 0.773},
#  {'acousticness': 0.688,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rgnBhdG2JDFTbYkYRZAku',
#   'danceability': 0.825,
#   'duration_ms': 209755,
#   'energy': 0.593,
#   'id': '1rgnBhdG2JDFTbYkYRZAku',
#   'instrumentalness': 0.000161,
#   'key': 6,
#   'liveness': 0.17,
#   'loudness': -6.401,
#   'mode': 0,
#   'speechiness': 0.0988,
#   'tempo': 98.078,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1rgnBhdG2JDFTbYkYRZAku',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1rgnBhdG2JDFTbYkYRZAku',
#   'valence': 0.54},
#  {'acousticness': 0.289,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6bLvfGI2XeU5DTl8feuNrk',
#   'danceability': 0.59,
#   'duration_ms': 227396,
#   'energy': 0.857,
#   'id': '6bLvfGI2XeU5DTl8feuNrk',
#   'instrumentalness': 4.21e-06,
#   'key': 10,
#   'liveness': 0.0414,
#   'loudness': -1.986,
#   'mode': 0,
#   'speechiness': 0.0553,
#   'tempo': 135.29,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/6bLvfGI2XeU5DTl8feuNrk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6bLvfGI2XeU5DTl8feuNrk',
#   'valence': 0.976},
#  {'acousticness': 0.143,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mAN61JH0dzyZpWslS11jy',
#   'danceability': 0.879,
#   'duration_ms': 199711,
#   'energy': 0.703,
#   'id': '6mAN61JH0dzyZpWslS11jy',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.0569,
#   'loudness': -4.219,
#   'mode': 1,
#   'speechiness': 0.0701,
#   'tempo': 94.004,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6mAN61JH0dzyZpWslS11jy',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6mAN61JH0dzyZpWslS11jy',
#   'valence': 0.788},
#  {'acousticness': 0.0377,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EO0tGvdBCw6vdChaNvVlc',
#   'danceability': 0.869,
#   'duration_ms': 133880,
#   'energy': 0.422,
#   'id': '3EO0tGvdBCw6vdChaNvVlc',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.253,
#   'loudness': -8.151,
#   'mode': 1,
#   'speechiness': 0.523,
#   'tempo': 138.006,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3EO0tGvdBCw6vdChaNvVlc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3EO0tGvdBCw6vdChaNvVlc',
#   'valence': 0.339},
#  {'acousticness': 0.238,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5m3jpKkgkfoMcym1qjToFg',
#   'danceability': 0.851,
#   'duration_ms': 259600,
#   'energy': 0.688,
#   'id': '5m3jpKkgkfoMcym1qjToFg',
#   'instrumentalness': 1.93e-05,
#   'key': 11,
#   'liveness': 0.105,
#   'loudness': -4.038,
#   'mode': 1,
#   'speechiness': 0.0565,
#   'tempo': 103.982,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5m3jpKkgkfoMcym1qjToFg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5m3jpKkgkfoMcym1qjToFg',
#   'valence': 0.732},
#  {'acousticness': 0.00473,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56Ta1O7Jxxpjnc6cWdDKUo',
#   'danceability': 0.574,
#   'duration_ms': 211652,
#   'energy': 0.634,
#   'id': '56Ta1O7Jxxpjnc6cWdDKUo',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.132,
#   'loudness': -5.979,
#   'mode': 0,
#   'speechiness': 0.333,
#   'tempo': 183.871,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/56Ta1O7Jxxpjnc6cWdDKUo',
#   'type': 'audio_features',
#   'uri': 'spotify:track:56Ta1O7Jxxpjnc6cWdDKUo',
#   'valence': 0.214},
#  {'acousticness': 0.731,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eJMfftS33KTjuF7lTsMCx',
#   'danceability': 0.726,
#   'duration_ms': 173333,
#   'energy': 0.431,
#   'id': '7eJMfftS33KTjuF7lTsMCx',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.696,
#   'loudness': -8.765,
#   'mode': 0,
#   'speechiness': 0.135,
#   'tempo': 144.026,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7eJMfftS33KTjuF7lTsMCx',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7eJMfftS33KTjuF7lTsMCx',
#   'valence': 0.348},
#  {'acousticness': 0.12,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tGENA8xef0wABdHvyXwv9',
#   'danceability': 0.737,
#   'duration_ms': 330240,
#   'energy': 0.832,
#   'id': '2tGENA8xef0wABdHvyXwv9',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.255,
#   'loudness': -2.622,
#   'mode': 0,
#   'speechiness': 0.0798,
#   'tempo': 173.986,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2tGENA8xef0wABdHvyXwv9',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2tGENA8xef0wABdHvyXwv9',
#   'valence': 0.865},
#  {'acousticness': 0.248,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2w8SKQCnT2YQK1qCqKl2uW',
#   'danceability': 0.777,
#   'duration_ms': 154286,
#   'energy': 0.656,
#   'id': '2w8SKQCnT2YQK1qCqKl2uW',
#   'instrumentalness': 2.06e-06,
#   'key': 2,
#   'liveness': 0.139,
#   'loudness': -5.823,
#   'mode': 0,
#   'speechiness': 0.158,
#   'tempo': 168.103,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2w8SKQCnT2YQK1qCqKl2uW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2w8SKQCnT2YQK1qCqKl2uW',
#   'valence': 0.833},
#  {'acousticness': 0.0816,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lCkncy6bIB0LTMT7kvrD1',
#   'danceability': 0.843,
#   'duration_ms': 205933,
#   'energy': 0.836,
#   'id': '2lCkncy6bIB0LTMT7kvrD1',
#   'instrumentalness': 0.00138,
#   'key': 11,
#   'liveness': 0.0532,
#   'loudness': -2.474,
#   'mode': 0,
#   'speechiness': 0.0695,
#   'tempo': 94.018,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2lCkncy6bIB0LTMT7kvrD1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2lCkncy6bIB0LTMT7kvrD1',
#   'valence': 0.65},
#  {'acousticness': 0.114,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DjInVTE03icrWsq2UZV9n',
#   'danceability': 0.797,
#   'duration_ms': 200961,
#   'energy': 0.639,
#   'id': '3DjInVTE03icrWsq2UZV9n',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.0589,
#   'loudness': -4.317,
#   'mode': 1,
#   'speechiness': 0.387,
#   'tempo': 175.94,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3DjInVTE03icrWsq2UZV9n',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3DjInVTE03icrWsq2UZV9n',
#   'valence': 0.677},
#  {'acousticness': 0.142,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4GGwM2Krtlx9G9ii1RaEOx',
#   'danceability': 0.795,
#   'duration_ms': 304733,
#   'energy': 0.715,
#   'id': '4GGwM2Krtlx9G9ii1RaEOx',
#   'instrumentalness': 1.9e-06,
#   'key': 1,
#   'liveness': 0.179,
#   'loudness': -3.583,
#   'mode': 1,
#   'speechiness': 0.0836,
#   'tempo': 165.95,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4GGwM2Krtlx9G9ii1RaEOx',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4GGwM2Krtlx9G9ii1RaEOx',
#   'valence': 0.751},
#  {'acousticness': 0.493,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16DNJ8y6k97DxuMyV49W7V',
#   'danceability': 0.706,
#   'duration_ms': 153560,
#   'energy': 0.622,
#   'id': '16DNJ8y6k97DxuMyV49W7V',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.102,
#   'loudness': -6.032,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 90.022,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/16DNJ8y6k97DxuMyV49W7V',
#   'type': 'audio_features',
#   'uri': 'spotify:track:16DNJ8y6k97DxuMyV49W7V',
#   'valence': 0.615},
#  {'acousticness': 0.013,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zEgnpM0qYmHLDnh8WPejL',
#   'danceability': 0.641,
#   'duration_ms': 157733,
#   'energy': 0.857,
#   'id': '6zEgnpM0qYmHLDnh8WPejL',
#   'instrumentalness': 0.00534,
#   'key': 1,
#   'liveness': 0.0695,
#   'loudness': -5.725,
#   'mode': 0,
#   'speechiness': 0.301,
#   'tempo': 122.728,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/6zEgnpM0qYmHLDnh8WPejL',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6zEgnpM0qYmHLDnh8WPejL',
#   'valence': 0.961},
#  {'acousticness': 0.297,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Ol5LmdNDNpFu1oNwfgkux',
#   'danceability': 0.727,
#   'duration_ms': 179339,
#   'energy': 0.838,
#   'id': '1Ol5LmdNDNpFu1oNwfgkux',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0603,
#   'loudness': -2.435,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'tempo': 145.995,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1Ol5LmdNDNpFu1oNwfgkux',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1Ol5LmdNDNpFu1oNwfgkux',
#   'valence': 0.933}]
